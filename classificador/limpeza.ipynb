# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from sqlite3 import Error
from sklearn.ensemble import RandomForestClassifier
import sqlite3
import pickle
# %matplotlib inline
try:
    conn = sqlite3.connect("training_V2.db")
except Error as e:
    print(e)
# df1.to_excel(r'C:\Users\Antonio Fonseca\Desktop\BLOX\ementas.xlsx')
# n esquecer do tensorflow

# %%
df = pd.read_excel('atual.xlsx')
df.shape
# Out:
# (4633, 2)

# %%
df["ÁREA DO CONHECIMENTO"].value_counts()
# Out:
# Engenharia, Produção e Construção            654
# Ciências Naturais                            588
# Saúde e Bem-Estar Social                     587
# Ciências Sociais, Jornalismo e Informação    509
# Humanidades e Linguagens                     385
# Matemática e Computação                      333
# Negócios e Administração                     321
# Direito                                      279
# Agricultura e Veterinária                    246
# Educação                                     200
# programas genericos                          161
# Serviços                                     142
# Psicologia e Desenvolvimento                 137
# Programas Interdisciplinares                  91
# Name: ÁREA DO CONHECIMENTO, dtype: int64

# %%
data = pd.read_excel('ementas.xlsx')
data.shape
# Out:
# (10165, 7)

# %%
data.head()
# Out:
#    Unnamed: 0                                           materias  \
# 0           0  Práticas Multidisciplinares em Canto Coral, co...
# 1           1                         Introdução à Computação II
# 2           2      Análise Ambiental: Gestão de Áreas Protegidas
# 3           3                       Práticas Interpretativas III
# 4           4                               Ações Comunitárias I
#
#                                               escola  \
# 0                     Escola de Comunicações e Artes
# 1  Faculdade de Filosofia, Ciências e Letras de R...
# 2                 Escola de Engenharia de São Carlos
# 3  Faculdade de Filosofia, Ciências e Letras de R...
# 4                            Instituto de Psicologia
#
#                                                  obj  \
# 0  1- Oferecer aos alunos do conjunto de discipli...
# 1  Introduzir os conceitos básicos de projeto e a...
# 2  Discutir a importância do estabelecimento de e...
# 3  Introduzir aos alunos de instrumento uma noção...
# 4  Exposição do aluno a situações comunitárias, s...
#
#                                                  p_r  \
# 0  1.Estágio no Coral Escola Comunicantus e no Co...
# 1  Análise de complexidade de algoritmos; Paradig...
# 2  1. Apresentação da disciplina, do professor e ...
# 3  Estudar os estilos de interpretação dentro do ...
# 4  Exposição do aluno a situações comunitárias, s...
#
#                                             programa  ÁREA DO CONHECIMENTO
# 0  1.Estágio no Coral Escola Comunicantus e no Co...                   NaN
# 1                                                NaN                   NaN
# 2  1. Apresentação da disciplina, do professor e ...                   NaN
# 3  – Estudar os estilos de interpretação dentro d...                   NaN
# 4  "\tExperiência de observação ou observação par...                   NaN

# %%
data = data.sort_values('materias', ascending=True)
data.head()
# Out:
#       Unnamed: 0                                           materias  \
# 7              7  "Arte dos anos 1960 à atualidade: explorando f...
# 6487        6487  (Des) Construção de traje de cena  e cenografi...
# 1790        1790  (Des) Construção de traje de cena e cenografia...
# 2040        2040  A Abordagem Qualitativa na Pesquisa em Psicolo...
# 3433        3433                            A Cidade Constitucional
#
#                                        escola  \
# 7              Escola de Comunicações e Artes
# 6487           Escola de Comunicações e Artes
# 1790           Escola de Comunicações e Artes
# 2040                  Instituto de Psicologia
# 3433  Escola de Artes, Ciências e Humanidades
#
#                                                     obj  \
# 7     1. Oferecer aos estudantes um quadro geral das...
# 6487  Discutir o traje de cena contemporâneo a parti...
# 1790  Traçar amplo panorama da inserção do traje de ...
# 2040  Pretende fornecer elementos para que os alunos...
# 3433  A Cidade Constitucional é um projeto de extens...
#
#                                                     p_r  \
# 7     Discussão de temas previamente propostos em se...
# 6487  O traje de cena popular – origens e trajetória...
# 1790  A cena queer\nÉ da Disney, sim, e daí? Cenogra...
# 2040                                                NaN
# 3433  Disciplina de campo ligada ao Direito Constitu...
#
#                                                programa  ÁREA DO CONHECIMENTO
# 7     1. A tradição humanista europeia posta em xequ...                   NaN
# 6487  1-O traje de cena popular – origens e trajetór...                   NaN
# 1790  1- Breve histórico do traje de cena e cenograf...                   NaN
# 2040  1. Introdução à abordagem qualitativa na pesqu...                   NaN
# 3433  Conteúdo: Aulas teóricas e práticas\n\nAs aula...                   NaN

# %%
teste = df.merge(data, on= ["materias"],how ="inner" )

# %%
teste.head()
# Out:
#                                             materias ÁREA DO CONHECIMENTO_x  \
# 0                         Acolhimento em Emergências    programas genericos
# 1            Apoio à Escolha da Especialidade Médica    programas genericos
# 2  Atividades Acadêmicas Científicas, de Extensão...    programas genericos
# 3  Atividades Acadêmicas Científicas, de Extensão...    programas genericos
# 4  Atividades Acadêmico-Científico-Culturais I (A...    programas genericos
#
#    Unnamed: 0                                             escola  \
# 0        3278            Faculdade de Medicina de Ribeirão Preto
# 1        1859            Faculdade de Medicina de Ribeirão Preto
# 2        5117  Instituto de Ciências Matemáticas e de Computação
# 3        8285  Instituto de Ciências Matemáticas e de Computação
# 4         176  Pró-Reitoria de Graduação  - Cursos Interunidades
#
#                                                  obj  \
# 0  1. Compreender os desafios ético-sociais envol...
# 1  Compreender os principais fatores que influenc...
# 2  Estimular a pró-atividade dos alunos, incentiv...
# 3  Estimular a pró-atividade dos alunos, incentiv...
# 4                                                NaN
#
#                                                  p_r  \
# 0  O Objetivo geral é que o aluno tenha noção do ...
# 1  Estudo de fatores ligados ao estudante e à nat...
# 2  São computadas as participações em: atividades...
# 3  São computadas as participações em: atividades...
# 4                                                NaN
#
#                                             programa  ÁREA DO CONHECIMENTO_y
# 0  Atividades Teóricas: \n1.Macro e Micro regulaç...                     NaN
# 1  Fatores que influenciam a escolha da especiali...                     NaN
# 2  1. Atividades de extensão: cursos de difusão c...                     NaN
# 3  1. Atividades de extensão: cursos de difusão c...                     NaN
# 4                                                NaN                     NaN

# %%
teste = teste.drop(['Unnamed: 0', 'escola','ÁREA DO CONHECIMENTO_y'], axis=1)

# %%
teste.to_csv(r'C:\Users\Antonio Fonseca\Desktop\BLOX\treino.csv')
