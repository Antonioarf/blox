# %%
import pandas as pd;
import seaborn as sns # evite fazer pairplot! Estoura a memória
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon, binom, t, norm, probplot, scoreatpercentile, percentileofscore
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
# %matplotlib inline

# %%
df = pd.read_csv('ementas(8).csv')
df.shape
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-31-8defb5e4a555> in <module>
# ----> 1 df = pd.read_csv('ementas(8).csv')
#       2 df.shape
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1578426498-1378  https://uspdigital.usp.br/jupiterweb/jupColegi...
# 1   1578432193-2590  https://uspdigital.usp.br/jupiterweb/jupColegi...
# 2   1578446984-3576  https://uspdigital.usp.br/jupiterweb/jupColegi...
#
#                                               escola  \
# 0  Faculdade de Filosofia, Letras e Ciências Humanas
# 1   Escola Superior de Agricultura "Luiz de Queiroz"
# 2            Escola de Artes, Ciências e Humanidades
#
#                                          escola-href  \
# 0  https://uspdigital.usp.br/jupiterweb/jupColegi...
# 1  https://uspdigital.usp.br/jupiterweb/jupColegi...
# 2  https://uspdigital.usp.br/jupiterweb/jupColegi...
#
#                   ordem_alfabetica  \
# 0  Disciplinas em ordem alfabética
# 1  Disciplinas em ordem alfabética
# 2  Disciplinas em ordem alfabética
#
#                                ordem_alfabetica-href  \
# ...

# %%
data = pd.DataFrame(data=[df["materia"],df["objetivos"],df["programa_resumido"],df["programa"],df["avaliacao"]])
data = data.transpose()
data.head()
# Out:
#                                          materia  \
# 0             Introdução aos Estudos Clássicos I
# 1    Estágio Vivencial em Ciências dos Alimentos
# 2                               Gestão de Marcas
# 3  Fundamentos Biológicos da Atividade Física IV
# 4                  Introdução à Teoria da Medida
#
#                                            objetivos  \
# 0  Fornecer um repertório de textos representativ...
# 1  Aprimorar a formação cultural, social e técnic...
# 2  Discutir os conceitos de marca, identidade e d...
# 3  •      Aprofundar princípios de construção e f...
# 4  Introduzir  à teoria da medida na reta e relac...
#
#                                    programa_resumido  \
# 0  Apresentação de gêneros de poesia hexamétrica ...
# 1  O conteúdo do programa será elaborado, de comu...
# 2  A disciplina abordará os conceitos básicos, as...
# 3  Módulo I - Sistema Endócrino\nMódulo II - Ativ...
# 4  Medida de Lebesgue. Conjuntos e funções mensur...
#
# ...

# %%
# data = shuffle(data)
# X_train, X_test, y_train, y_test = train_test_split(data,coluna_resultado,test_size=0.15, random_state = 42)

# %%
# nb = Pipeline([('vect', CountVectorizer()),
#                ('tfidf', TfidfTransformer()),
#                ('clf', MultinomialNB()),
#               ])
# nb.fit(X_train, y_train)

# %time

# y_pred = nb.predict(X_test)

# print('accuracy %s' % accuracy_score(y_pred, y_test))
# print(classification_report(y_test, y_pred,target_names=my_tags))

# %%
dff = pd.read_excel('excel.xlsx')
dff.shape
dff= pd.read_file.to_csv(dff)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-2a9ddff15898> in <module>
#       1 dff = pd.read_excel('excel.xlsx')
#       2 dff.shape
# ----> 3 dff= pd.read_file.to_csv(dff)
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'read_file'

# %%
dff.tail(10)
# Out:
#        web-scraper-order,web-scraper-start-url,escola,escola-href,ordem_alfabetica,ordem_alfabetica-href,materia,materia-href,mais_info,mais_info-href,objetivos,programa_resumido,programa,avaliacao,bibliografia  \
# 106410          as Informações da Disciplina LES0250",...
# 106411  1578436440-2908,"https://uspdigital.usp.br/jup...
# 106412          as Informações da Disciplina SET0415",...
# 106413  SOUZA, J.C.A.O., ANTUNES, H.M.C.C. Processos G...
# 106414  SOUZA, J.C.A.O., ANTUNES, H.M.C.C. Cargas Móve...
# 106415  SUSSEKIND, J.C. Curso de Análise Estrutural. V...
# 106416  CAMPANARI, F.A. Teoria das Estruturas. Vol. 1,...
# 106417  BORESI, A.P., SCHIMIDT, R.J. Estática. São Pau...
# 106418  1578426260-1328,"https://uspdigital.usp.br/jup...
# 106419          as Informações da Disciplina MCG0656",...
#
#                                                Unnamed: 1  \
# 106410  b)Dar ao aluno a chance de aplicar, durante o ...
# ...

# %%
dff.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-54f26e90b702> in <module>
# ----> 1 dff.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'
